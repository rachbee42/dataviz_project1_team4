# %%
# Dependencies
import pandas as pd
from pathlib import Path
import scipy.stats as st
import csv

# %%
# Data filepaths
data_residence = Path("Base Data/data_residence.csv")

# %%
# Read the data 
data_residence_df = pd.read_csv(data_residence, encoding="ISO-8859-1")

# %%
# List of columns within the DataFrame
data_residence_df.columns
# Out:
# Index(['Area of usual residence (code)', 'Area of usual residence (name)',
#        'Area of usual residence (geography)', 'Live births', 'Stillbirths',
#        'Perinatal deaths', 'Neonatal deaths', 'Postneonatal deaths',
#        'Infant deaths', 'Stillbirth rate', 'Stillbirth unreliable indicator ',
#        'Perinatal mortality rate', 'Perinatal unreliable indicator ',
#        'Neonatal mortality rate', 'Neonatal unreliable indicator',
#        'Postneonatal mortality rate', 'Postneonatal unreliable indicator',
#        'Infant mortality rate', 'Infant unreliable indicator '],
#       dtype='object')

# %%
# Delete columns not required
data_reduced_df = data_residence_df
data_reduced_df = data_reduced_df.drop(columns=['Stillbirth rate', 'Stillbirth unreliable indicator ', 'Perinatal mortality rate', 'Perinatal unreliable indicator ', 'Neonatal mortality rate', 'Neonatal unreliable indicator', 'Postneonatal mortality rate', 'Postneonatal unreliable indicator', 'Infant mortality rate', 'Infant unreliable indicator '])
data_reduced_df.head()
# Out:
#   Area of usual residence (code) Area of usual residence (name)  \
# 0           K04000001, J99000001   ENGLAND, WALES AND ELSEWHERE
# 1                      K04000001              ENGLAND AND WALES
# 2                      E92000001                        ENGLAND
# 3                      E12000001                     NORTH EAST
# 4                      E06000047                  County Durham
#
#   Area of usual residence (geography) Live births Stillbirths  \
# 0                             Country     624,828       2,597
# 1                             Country     624,729       2,577
# 2                             Country     595,948       2,451
# 3                              Region      25,153         103
# 4                   Unitary Authority       4,592          17
#
#   Perinatal deaths Neonatal deaths  Postneonatal deaths Infant deaths
# 0            3,950           1,715                608.0         2,323
# 1            3,927           1,709                603.0         2,312
# 2            3,747           1,633                576.0         2,209
# 3              149              61                 26.0            87
# 4               27              14                  4.0            18

# %%
# Rename headers
reduced_df = data_reduced_df
reduced_df = reduced_df.rename(columns={"Area of usual residence (code)": "Area Code",
                                        "Area of usual residence (name)": "Area Name",
                                        "Area of usual residence (geography)": "Area Geography", })
reduced_df.head()
# Out:
#               Area Code                     Area Name     Area Geography  \
# 0  K04000001, J99000001  ENGLAND, WALES AND ELSEWHERE            Country
# 1             K04000001             ENGLAND AND WALES            Country
# 2             E92000001                       ENGLAND            Country
# 3             E12000001                    NORTH EAST             Region
# 4             E06000047                 County Durham  Unitary Authority
#
#   Live births Stillbirths Perinatal deaths Neonatal deaths  \
# 0     624,828       2,597            3,950           1,715
# 1     624,729       2,577            3,927           1,709
# 2     595,948       2,451            3,747           1,633
# 3      25,153         103              149              61
# 4       4,592          17               27              14
#
#    Postneonatal deaths Infant deaths
# 0                608.0         2,323
# 1                603.0         2,312
# 2                576.0         2,209
# 3                 26.0            87
# 4                  4.0            18

# %%
# Remove NaN rows
complete_df = reduced_df.dropna(how='any')
complete_df.count()
# Out:
# Area Code              376
# Area Name              376
# Area Geography         376
# Live births            376
# Stillbirths            376
# Perinatal deaths       376
# Neonatal deaths        376
# Postneonatal deaths    376
# Infant deaths          376
# dtype: int64

# %%
# Verify NaN rows removed
display(complete_df.iloc[:])
# Out:
#                 Area Code                                          Area Name  \
# 0    K04000001, J99000001                       ENGLAND, WALES AND ELSEWHERE
# 1               K04000001                                  ENGLAND AND WALES
# 2               E92000001                                            ENGLAND
# 3               E12000001                                         NORTH EAST
# 4               E06000047                                      County Durham
# ..                    ...                                                ...
# 371             W06000019                                      Blaenau Gwent
# 372             W06000020                                            Torfaen
# 373             W06000021                                      Monmouthshire
# 374             W06000022                                            Newport
# 375             J99000001  Usual r+A20:B386esidence outside England and W...
#
#         Area Geography Live births Stillbirths Perinatal deaths  \
# 0              Country     624,828       2,597            3,950
# 1              Country     624,729       2,577            3,927
# 2              Country     595,948       2,451            3,747
# 3               Region      25,153         103              149
# 4    Unitary Authority       4,592          17               27
# ..                 ...         ...         ...              ...
# 371  Unitary Authority         673           2                2
# 372  Unitary Authority         943           4                5
# 373  Unitary Authority         727           3                5
# 374  Unitary Authority       1,890          12               16
# 375            Country          99          20               23
#
#     Neonatal deaths  Postneonatal deaths Infant deaths
# 0             1,715                608.0         2,323
# 1             1,709                603.0         2,312
# 2             1,633                576.0         2,209
# 3                61                 26.0            87
# 4                14                  4.0            18
# ..              ...                  ...           ...
# 371               1                  0.0             1
# 372               2                  1.0             3
# 373               2                  0.0             2
# 374               7                  2.0             9
# 375               6                  5.0            11
#
# [376 rows x 9 columns]

# %%
# Return data by Region only
region_df = complete_df[complete_df['Area Geography'].str.contains('Region')]
display(region_df)
# Out:
#      Area Code                 Area Name Area Geography Live births  \
# 3    E12000001                NORTH EAST         Region      25,153
# 17   E12000002                NORTH WEST         Region      78,127
# 61   E12000003  YORKSHIRE AND THE HUMBER         Region      56,377
# 86   E12000004             EAST MIDLANDS         Region      47,860
# 126  E12000005             WEST MIDLANDS         Region      63,846
# 161  E12000006                      EAST         Region      67,054
# 212  E12000007                    LONDON         Region     110,961
# 248  E12000008                SOUTH EAST         Region      94,292
# 319  E12000009                SOUTH WEST         Region      52,278
#
#     Stillbirths Perinatal deaths Neonatal deaths  Postneonatal deaths  \
# 3           103              149              61                 26.0
# 17          345              504             218                 95.0
# 61          259              405             175                 62.0
# 86          203              309             138                 53.0
# 126         289              523             288                 72.0
# 161         252              376             160                 54.0
# 212         481              689             257                110.0
# 248         343              540             239                 72.0
# 319         176              252              97                 32.0
#
#     Infant deaths
# 3              87
# 17            313
# 61            237
# 86            191
# 126           360
# 161           214
# 212           367
# 248           311
# 319           129

# %%
# Convert required columns as a integers
region_df = region_df.astype({'Stillbirths':'int'})
region_df = region_df.astype({'Perinatal deaths':'int'})
region_df = region_df.astype({'Neonatal deaths':'int'})
region_df = region_df.astype({'Postneonatal deaths':'int'})
region_df = region_df.astype({'Infant deaths':'int'})
display(region_df)
# Out:
#      Area Code                 Area Name Area Geography Live births  \
# 3    E12000001                NORTH EAST         Region      25,153
# 17   E12000002                NORTH WEST         Region      78,127
# 61   E12000003  YORKSHIRE AND THE HUMBER         Region      56,377
# 86   E12000004             EAST MIDLANDS         Region      47,860
# 126  E12000005             WEST MIDLANDS         Region      63,846
# 161  E12000006                      EAST         Region      67,054
# 212  E12000007                    LONDON         Region     110,961
# 248  E12000008                SOUTH EAST         Region      94,292
# 319  E12000009                SOUTH WEST         Region      52,278
#
#      Stillbirths  Perinatal deaths  Neonatal deaths  Postneonatal deaths  \
# 3            103               149               61                   26
# 17           345               504              218                   95
# 61           259               405              175                   62
# 86           203               309              138                   53
# 126          289               523              288                   72
# 161          252               376              160                   54
# 212          481               689              257                  110
# 248          343               540              239                   72
# 319          176               252               97                   32
#
#      Infant deaths
# 3               87
# 17             313
# 61             237
# 86             191
# 126            360
# 161            214
# 212            367
# 248            311
# 319            129

# %%
# Display sum of rows
region_deaths_sum  = region_df.sum(axis=1, numeric_only=True)
display(region_deaths_sum)
# Out:
# 3       426
# 17     1475
# 61     1138
# 86      894
# 126    1532
# 161    1056
# 212    1904
# 248    1505
# 319     686
# dtype: int64

# %%
# Display totals as a new column
region_total_df = region_df.assign(Total_deaths=region_deaths_sum)

# Display the DataFrame with the new 'Total deaths' column
display(region_total_df)
# Out:
#      Area Code                 Area Name Area Geography Live births  \
# 3    E12000001                NORTH EAST         Region      25,153
# 17   E12000002                NORTH WEST         Region      78,127
# 61   E12000003  YORKSHIRE AND THE HUMBER         Region      56,377
# 86   E12000004             EAST MIDLANDS         Region      47,860
# 126  E12000005             WEST MIDLANDS         Region      63,846
# 161  E12000006                      EAST         Region      67,054
# 212  E12000007                    LONDON         Region     110,961
# 248  E12000008                SOUTH EAST         Region      94,292
# 319  E12000009                SOUTH WEST         Region      52,278
#
#      Stillbirths  Perinatal deaths  Neonatal deaths  Postneonatal deaths  \
# 3            103               149               61                   26
# 17           345               504              218                   95
# 61           259               405              175                   62
# 86           203               309              138                   53
# 126          289               523              288                   72
# 161          252               376              160                   54
# 212          481               689              257                  110
# 248          343               540              239                   72
# 319          176               252               97                   32
#
#      Infant deaths  Total_deaths
# 3               87           426
# 17             313          1475
# 61             237          1138
# 86             191           894
# 126            360          1532
# 161            214          1056
# 212            367          1904
# 248            311          1505
# 319            129           686

# %%
# Rename headers
revised_df = region_total_df
revised_df = revised_df.rename(columns={"Total_deaths": "Total deaths"})
print("Value of row 1")
display(revised_df.iloc[:])
# Out:
# Value of row 1
#      Area Code                 Area Name Area Geography Live births  \
# 3    E12000001                NORTH EAST         Region      25,153
# 17   E12000002                NORTH WEST         Region      78,127
# 61   E12000003  YORKSHIRE AND THE HUMBER         Region      56,377
# 86   E12000004             EAST MIDLANDS         Region      47,860
# 126  E12000005             WEST MIDLANDS         Region      63,846
# 161  E12000006                      EAST         Region      67,054
# 212  E12000007                    LONDON         Region     110,961
# 248  E12000008                SOUTH EAST         Region      94,292
# 319  E12000009                SOUTH WEST         Region      52,278
#
#      Stillbirths  Perinatal deaths  Neonatal deaths  Postneonatal deaths  \
# 3            103               149               61                   26
# 17           345               504              218                   95
# 61           259               405              175                   62
# 86           203               309              138                   53
# 126          289               523              288                   72
# 161          252               376              160                   54
# 212          481               689              257                  110
# 248          343               540              239                   72
# 319          176               252               97                   32
#
#      Infant deaths  Total deaths
# 3               87           426
# 17             313          1475
# 61             237          1138
# 86             191           894
# 126            360          1532
# 161            214          1056
# 212            367          1904
# 248            311          1505
# 319            129           686

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import random

# Create an array that contains the number of users each region has
deaths = [426, 1475, 1138, 894, 1532, 1056, 1904, 1505, 686]
x_axis = np.arange(len(deaths))

# %%
# Create bar chart, label and set limits for x and y axis
plt.bar(x_axis, deaths, color='b', alpha=0.5, align="center")
labels_x = [value for value in x_axis]
plt.xticks(labels_x, ["NE", "NW", "Y&H", "EM", "WM", "East", "London", "SE", "SW"])
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(deaths)+250)
plt.xlabel("Region")
plt.ylabel("Total number of infant deaths")

# Name chart_1
plt.title("Total infant deaths (<1 year) in England, during 2021 by Region")
plt.show()

# %%
# Save chart
plt.savefig("Base Data/Bar_Chart_Total_Deaths.png")
plt.show()

# %%
# Create an array that contains the number of births each region has
live_births = [25153, 78127, 56377, 47860, 63846, 67054, 110961, 94292, 52278]
x_axis = np.arange(len(live_births))

# %%
# Create bar chart, label and set limits for x and y axis - Number of live births
plt.bar(x_axis, live_births, color='g', alpha=0.5, align="center")
labels_x = [value for value in x_axis]
plt.xticks(labels_x, ["NE", "NW", "Y&H", "EM", "WM", "East", "London", "SE", "SW"])
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(live_births)+10000)
plt.xlabel("Region")
plt.ylabel("Total number of live births")

# Name chart_2
plt.title("Total live births in England, during 2021 by Region")
plt.show()

# %%
# Save chart
plt.savefig("Base Data/Bar_Chart_Live_Births.png")
plt.show()

# %%
# Reduce columns further to return only live births and 
reduced_totalbirths_df = revised_df
reduced_totalbirths_df = reduced_totalbirths_df.drop(columns=['Stillbirths', 'Perinatal deaths', 'Neonatal deaths', 'Postneonatal deaths', 'Infant deaths'])
reduced_totalbirths_df.head()
print("Value of row 1")
display(reduced_totalbirths_df.iloc[:])
# Out:
# Value of row 1
#      Area Code                 Area Name Area Geography Live births  \
# 3    E12000001                NORTH EAST         Region      25,153
# 17   E12000002                NORTH WEST         Region      78,127
# 61   E12000003  YORKSHIRE AND THE HUMBER         Region      56,377
# 86   E12000004             EAST MIDLANDS         Region      47,860
# 126  E12000005             WEST MIDLANDS         Region      63,846
# 161  E12000006                      EAST         Region      67,054
# 212  E12000007                    LONDON         Region     110,961
# 248  E12000008                SOUTH EAST         Region      94,292
# 319  E12000009                SOUTH WEST         Region      52,278
#
#      Total deaths
# 3             426
# 17           1475
# 61           1138
# 86            894
# 126          1532
# 161          1056
# 212          1904
# 248          1505
# 319           686

# %%
# Convert columns as a float

#reduced_totalbirths_df['Live births'] = reduced_totalbirths_df.astype['Live births'].str.replace(',', '').astype(float)
#reduced_totalbirths_df['Stillbirths'] = reduced_totalbirths_df.astype['Stillbirths'].str.replace(',', '').astype(float)
totalbirths_df = reduced_totalbirths_df.astype({'Live births':'str'})
totalbirths_df = reduced_totalbirths_df.astype({'Total deaths':'int'})

display(totalbirths_df)
# Out:
#      Area Code                 Area Name Area Geography Live births  \
# 3    E12000001                NORTH EAST         Region      25,153
# 17   E12000002                NORTH WEST         Region      78,127
# 61   E12000003  YORKSHIRE AND THE HUMBER         Region      56,377
# 86   E12000004             EAST MIDLANDS         Region      47,860
# 126  E12000005             WEST MIDLANDS         Region      63,846
# 161  E12000006                      EAST         Region      67,054
# 212  E12000007                    LONDON         Region     110,961
# 248  E12000008                SOUTH EAST         Region      94,292
# 319  E12000009                SOUTH WEST         Region      52,278
#
#      Total deaths
# 3             426
# 17           1475
# 61           1138
# 86            894
# 126          1532
# 161          1056
# 212          1904
# 248          1505
# 319           686

# %%
# Find total births (live births and deaths)
totalbirths_sum  = totalbirths_df.sum(axis=1, numeric_only=True)
display(totalbirths_sum)
# Out:
# 3       426
# 17     1475
# 61     1138
# 86      894
# 126    1532
# 161    1056
# 212    1904
# 248    1505
# 319     686
# dtype: int64

# %%
# Display totals as a new column
totalbirths_sum_df = totalbirths_df.assign(Total_births=totalbirths_sum)

# Display the DataFrame with the new 'Total births' column
display(totalbirths_sum_df)
# Out:
#      Area Code                 Area Name Area Geography Live births  \
# 3    E12000001                NORTH EAST         Region      25,153
# 17   E12000002                NORTH WEST         Region      78,127
# 61   E12000003  YORKSHIRE AND THE HUMBER         Region      56,377
# 86   E12000004             EAST MIDLANDS         Region      47,860
# 126  E12000005             WEST MIDLANDS         Region      63,846
# 161  E12000006                      EAST         Region      67,054
# 212  E12000007                    LONDON         Region     110,961
# 248  E12000008                SOUTH EAST         Region      94,292
# 319  E12000009                SOUTH WEST         Region      52,278
#
#      Total deaths  Total_births
# 3             426           426
# 17           1475          1475
# 61           1138          1138
# 86            894           894
# 126          1532          1532
# 161          1056          1056
# 212          1904          1904
# 248          1505          1505
# 319           686           686

# %%
# Create an array that contains the number of births each region has
deaths = [426, 1475, 1138, 894, 1532, 1056, 1904, 1505, 686]
total_births = [25579, 79602, 57515, 48754, 65378, 68110, 112865, 95797, 52964]
x_axis = np.arange(len(live_births))

# %%
# Create bar chart, label and set limits for x and y axis - Total live births vs deaths)
plt.bar(x_axis, deaths, color='b', alpha=0.5, align="center")
plt.bar(x_axis, total_births, color='g', alpha=0.5, align="center")

labels_x = [value for value in x_axis]
plt.xticks(labels_x, ["NE", "NW", "Y&H", "EM", "WM", "East", "London", "SE", "SW"])
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(live_births)+10000)
plt.xlabel("Region")
plt.ylabel("Total number of births and deaths")

# Name chart_3
plt.title("Total births versus infant deaths (<1 year old) in England, during 2021 by Region")
plt.show()

# %%
######STILL WORKING ON BELOW####
#add labels to above chart
